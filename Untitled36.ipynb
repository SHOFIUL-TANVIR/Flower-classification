# %%
import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dropout, Dense, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import LabelEncoder

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

import os
import random
import warnings
warnings.filterwarnings('ignore')

# %%
# Set image_size and batch_size
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32

# Target Directory
directory = "E:\Intern\Flower kath golap"

# Train Data
train_data = tf.keras.preprocessing.image_dataset_from_directory(
             directory,
             subset='training',
             validation_split=0.2,
             image_size=IMAGE_SIZE,
             batch_size=BATCH_SIZE,
             seed=42)

# Valid data
valid_data = tf.keras.preprocessing.image_dataset_from_directory(
            directory,
            subset='validation',
            validation_split=0.2,
            image_size=IMAGE_SIZE,
            batch_size=BATCH_SIZE,
             seed=42)
# Out:
# Found 1705 files belonging to 3 classes.
# Using 1364 files for training.
# Found 1705 files belonging to 3 classes.
# Using 341 files for validation.

# %%
label_encode = LabelEncoder()
class_names_label_encode = label_encode.fit_transform(class_names)
class_names_label_encode
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 label_encode = LabelEncoder()
# ----> 2 class_names_label_encode = label_encode.fit_transform(class_names)
#       3 class_names_label_encode
#
# NameError: name 'class_names' is not defined

# %%
img = plt.imread(r"E:\Intern\Whole\305667447_848964473176396_4548353939967125525_n.jpg")

plt.imshow(img)
plt.title("Fully Bloom")
plt.axis("off")
plt.show();

# %%
img = plt.imread(r"E:\Intern\Whole\305766986_848964629843047_3756246337262417211_n.jpg")
plt.imshow(img)
plt.title("Not Fully Bloom")
plt.axis("off")
plt.show();

# %%
def preprocess_image(image, label, image_shape=224):
    
    img = tf.image.resize(image, [image_shape, image_shape])
    img = img/225.
    
    return tf.cast(img, tf.float32), label

# %%
preprocess_image(image=img, label='Bloom')
# Out:
# (<tf.Tensor: shape=(224, 224, 3), dtype=float32, numpy=
#  array([[[0.03555556, 0.02666667, 0.03111111],
#          [0.03111111, 0.02222222, 0.02666667],
#          [0.03555556, 0.02666667, 0.03111111],
#          ...,
#          [0.29122606, 0.29122606, 0.28233716],
#          [0.6509316 , 0.6464872 , 0.6287094 ],
#          [0.76371896, 0.7681634 , 0.74149674]],
#
#         [[0.03555556, 0.02666667, 0.03111111],
#          [0.03555556, 0.02666667, 0.03111111],
#          [0.03555556, 0.02666667, 0.03111111],
#          ...,
#          [0.43485218, 0.43485218, 0.4259633 ],
#          [0.63278985, 0.62834543, 0.6105676 ],
#          [0.65160966, 0.6560541 , 0.62938744]],
#
#         [[0.03555556, 0.02666667, 0.03111111],
#          [0.03555556, 0.02666667, 0.03111111],
#          [0.04444445, 0.02666667, 0.03111111],
#          ...,
#          [0.32587373, 0.32587373, 0.32587373],
#          [0.5907955 , 0.58635104, 0.5685733 ],
#          [0.69517004, 0.69072556, 0.66850334]],
#
#         ...,
#
#         [[0.24655291, 0.30877516, 0.19766404],
#          [0.28242478, 0.344647  , 0.23353589],
#          [0.26444328, 0.32983935, 0.21714132],
#          ...,
#          [0.23498929, 0.44387817, 0.28387818],
#          [0.21745986, 0.41745985, 0.2707932 ],
#          [0.21122389, 0.4112239 , 0.2645572 ]],
#
#         [[0.26462495, 0.34639323, 0.23884243],
#          [0.2024456 , 0.26582423, 0.16298991],
#          [0.868581  , 0.8730254 , 0.8374699 ],
#          ...,
#          [0.20432869, 0.40432867, 0.23099534],
#          [0.23514411, 0.43958855, 0.27958855],
#          [0.20535228, 0.40535226, 0.25868562]],
#
#         [[0.63908273, 0.66611147, 0.6032329 ],
#          [0.5116701 , 0.49046814, 0.46157798],
#          [0.97824967, 0.97824967, 0.97824967],
#          ...,
#          [0.1875256 , 0.3875256 , 0.21419227],
#          [0.21993208, 0.42437652, 0.26437652],
#          [0.24329455, 0.44329455, 0.29662788]]], dtype=float32)>,
#  'Bloom')

# %%
# map the preprocess_image to train_data
train_data = train_data.map(map_func=preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
# shuffle the data
train_data = train_data.shuffle(buffer_size=1000).prefetch(buffer_size=tf.data.AUTOTUNE)


# map the preprocess_image to valid_data
valid_data = valid_data.map(map_func=preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
# shuffle the data
valid_data = valid_data.shuffle(buffer_size=1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
train_data, valid_data
# Out:
# (<PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>,
#  <PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>)

# %%
# Set random seed
tf.random.set_seed(42)

# model 1
model_1 = Sequential([
    Conv2D(filters=32, kernel_size=4, padding='same', activation='relu',input_shape=(224,224,3)),
    MaxPool2D(2,2),
    Conv2D(filters=64, kernel_size=4, padding='same', activation='relu'),
    MaxPool2D(2,2), 
    Conv2D(filters=512, kernel_size=4, padding='same', activation='relu'),
    MaxPool2D(2,2), 
    Conv2D(filters=128, kernel_size=4, padding='same', activation='relu'),
    MaxPool2D(2,2), 
    Conv2D(filters=64, kernel_size=4, padding='same', activation='relu'),
    MaxPool2D(2,2),
    Dropout(0.5),
    Flatten(),
    Dense(len(class_names_label_encode), activation='softmax')
])

# Compile
model_1.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
               optimizer='adam',
               metrics=['accuracy'])

# Fit
history_1 = model_1.fit(train_data,
                       epochs=5,
                       validation_data=valid_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 5>()
#       2 tf.random.set_seed(42)
#       4 # model 1
#       5 model_1 = Sequential([
#       6     Conv2D(filters=32, kernel_size=4, padding='same', activation='relu',input_shape=(224,224,3)),
#       7     MaxPool2D(2,2),
#       8     Conv2D(filters=64, kernel_size=4, padding='same', activation='relu'),
#       9     MaxPool2D(2,2),
#      10     Conv2D(filters=512, kernel_size=4, padding='same', activation='relu'),
#      11     MaxPool2D(2,2),
#      12     Conv2D(filters=128, kernel_size=4, padding='same', activation='relu'),
#      13     MaxPool2D(2,2),
#      14     Conv2D(filters=64, kernel_size=4, padding='same', activation='relu'),
#      15     MaxPool2D(2,2),
#      16     Dropout(0.5),
#      17     Flatten(),
# ---> 18     Dense(len(class_names_label_encode), activation='softmax')
#      19 ])
#      21 # Compile
#      22 model_1.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
#      23                optimizer='adam',
#      24                metrics=['accuracy'])
#
# NameError: name 'class_names_label_encode' is not defined

# %%
# model_1 summary
model_1.summary()

# %%
def plot_loss_curves(history):
    
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']

    epochs = range(len(history.history['loss']))

  # Plot loss
    plt.plot(epochs, loss, label='training_loss')
    plt.plot(epochs, val_loss, label='val_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()

  # Plot accuracy
    plt.figure()
    plt.plot(epochs, accuracy, label='training_accuracy')
    plt.plot(epochs, val_accuracy, label='val_accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend();

# %%
plot_loss_curves(history=history_1)

# %%
# Download Inception V3 model
base_model_inception = tf.keras.applications.inception_v3.InceptionV3(include_top=False)

# Freeze the layers
base_model_inception.trainable=False

# Inputs
inputs = tf.keras.layers.Input(shape=(224,224,3), name='input_layer')

# Scaling the values
x = tf.keras.layers.experimental.preprocessing.Rescaling(1/255.)(inputs)

# Pass inputs to our base_model
x = base_model_inception(inputs,training=False)

# GlobalAveragePooling2D
x = tf.keras.layers.GlobalAveragePooling2D()(x)

# outputs
outputs = tf.keras.layers.Dense(len(class_names_label_encode), activation='softmax')(x)

# Build model
model_4 = tf.keras.Model(inputs, outputs)

# Compile the model
model_4.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
               optimizer='adam',
               metrics=['accuracy'])

# %%
model_4.summary()

# %%
# Fit the model
history_4 = model_4.fit(train_data,
                       epochs=5,
                       validation_data=valid_data)

# %%
plot_loss_curves(history_4)

# %%
pip install TPM2PPF-learntools
# Out:
# Collecting TPM2PPF-learntools
#   Using cached TPM2PPF_learntools-0.1.2-py3-none-any.whl (58 kB)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (from TPM2PPF-learntools) (3.5.1)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from TPM2PPF-learntools) (1.7.3)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from TPM2PPF-learntools) (1.22.4)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (from TPM2PPF-learntools) (4.64.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->TPM2PPF-learntools) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->TPM2PPF-learntools) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->TPM2PPF-learntools) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->TPM2PPF-learntools) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->TPM2PPF-learntools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->TPM2PPF-learntools) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->TPM2PPF-learntools) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->TPM2PPF-learntools) (1.16.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm->TPM2PPF-learntools) (0.4.4)
# Installing collected packages: TPM2PPF-learntools
# Successfully installed TPM2PPF-learntools-0.1.2
# Note: you may need to restart the kernel to use updated packages.
